# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sna

# %% [markdown]
# ##### Uploading Data into df Variable

# %%
data = pd.read_csv('C:/Users/sitan/OneDrive/Desktop/Data Science/Python-14-Feb/DA_Python/movies.csv')

# %% [markdown]
# ##### Showing Data

# %%
Movie_Data = pd.DataFrame(data)
Movie_Data
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
Movie_Data.sample(10)
# Out:
#                                      MOVIES         YEAR  \
# 6485             Avatar: The Last Airbender  (2005–2008)
# 6853                        The Pentaverate         (II)
# 7005   La Reina de Indias y el Conquistador     (2020– )
# 5363            Hong Kong West Side Stories   (I) (2019)
# 8212                        Black Lightning  (2017–2021)
# 1754                                  Masum       (2017)
# 1476                           Premium Rush       (2012)
# 8411                  El desorden que dejas       (2020)
# 4334                      #TemanTapiMenikah       (2018)
# 946                               Greenleaf  (2016–2020)
#
#                                            GENRE  RATING  \
# 6485  \nAnimation, Action, Adventure                 9.6
# 6853                        \nComedy                 NaN
# 7005                \nDrama, History                 NaN
# 5363                 \nComedy, Drama                 7.3
# ...

# %% [markdown]
# ##### Finding Duplicate Row

# %%
duplicates = Movie_Data[Movie_Data.duplicated()]
duplicates
# Out:
#                     MOVIES      YEAR  \
# 6833   Mighty Little Bheem  (2019– )
# 6835   Mighty Little Bheem  (2019– )
# 6836   Mighty Little Bheem  (2019– )
# 6837   Mighty Little Bheem  (2019– )
# 6838   Mighty Little Bheem  (2019– )
# ...                    ...       ...
# 9989                  1899  (2022– )
# 9990                  1899  (2022– )
# 9991                  1899  (2022– )
# 9992                  1899  (2022– )
# 9994        The Imperfects  (2021– )
#
#                                           GENRE  RATING        ONE-LINE  \
# 6833  \nAnimation, Short, Adventure                 NaN  \nAdd a Plot\n
# 6835  \nAnimation, Short, Adventure                 9.0  \nAdd a Plot\n
# 6836  \nAnimation, Short, Adventure                 9.0  \nAdd a Plot\n
# 6837  \nAnimation, Short, Adventure                 NaN  \nAdd a Plot\n
# 6838  \nAnimation, Short, Adventure                 NaN  \nAdd a Plot\n
# ...                                         ...     ...             ...
# ...

# %% [markdown]
# ##### Before Removing Duplicate total Number of Rows is 9999. After Removing Duplicate Rows 9568. Total Number of Duplicate Row which is removed 431

# %%
Movie_Data.drop_duplicates(inplace=True,ignore_index=True)

# %% [markdown]
# ##### Cleaning Year Column

# %%
Movie_Data['YEAR'] = Movie_Data['YEAR'].str.extract(r'(\d{4})')
Movie_Data['YEAR']
# Out:
# 0       2021
# 1       2021
# 2       2010
# 3       2013
# 4       2021
#         ...
# 9563    2022
# 9564    2021
# 9565    2022
# 9566    2021
# 9567    2021
# Name: YEAR, Length: 9568, dtype: object

# %%
Movie_Data[(Movie_Data['YEAR'].isna()) & (Movie_Data['YEAR']!=None)][['MOVIES','YEAR']]
# Out:
#                  MOVIES YEAR
# 878   Vikings: Valhalla  NaN
# 1155         The Killer  NaN
# 1165             Hustle  NaN
# 1375      Resident Evil  NaN
# 1414           Bright 2  NaN
# ...                 ...  ...
# 9515       Pretty Smart  NaN
# 9516       Pretty Smart  NaN
# 9517       Pretty Smart  NaN
# 9518       Pretty Smart  NaN
# 9519       Pretty Smart  NaN
#
# [635 rows x 2 columns]

# %%
Movie_Data['STARS']=Movie_Data['STARS'].str.replace("\n","")

# %%
Movie_Data['ONE-LINE']=Movie_Data['ONE-LINE'].str.replace("\n"," ")

# %%
# Dictionary of movie index and release year
movie_years = {
    6243: 2025,   # Untitled Sean O'Keefe Project
    2947:2022,
    2948:2022,
    2948:2022,
    2959:2022,
    2753:2024,
    2779:2022,
    2804:2022,
    2832:2021,
    2846:2023,
    2522:2022,   
    2584:2022,
    2585:2022,
    2610:1991,
    2632:2022,
    2676:2022,
    2686:2025,
    2695:2022,
    2801:2022,
    2410:2022,
    2450:2023,
    2466:2023,
    2494:2022,
    2506:2021,
    2397:2022,
    2373:2022,
    2362:2022,
    2359:2023,
    2347:2023,
    2295:2023,
    2259:2015,
    2215:2015,
    2177:2025,
    2175:2004,
    2164:2022,
    2126:2022,
    2124:1978,
    2122:2023,
    2091:2021,
    2089:2024,
    2069:2022,
    2055:2023,
    2023:2024,
    1982:2011,
    1916:2024,
    1914:1999,
    1897:2023,
    1896:2022,
    1863:2022,
    1859:2022,
    1841:2024,
    1818:2024,
    1802:2024,
    1800:2025,
    1774:2022,
    1766:1988,
    1765:2025,
    1763:2020,
    1703:2023,
    1684:2022,
    1664:2024,
    1658:2024,
    1645:2024,
    1623:2023,
    1587:2022,
    1530:2024,
    1527:2022,
    1507:2012,
    1494:2022,
    1492:2023,
    1485:2022,
    1464:2019,
    1428:2023,
    1425:2022,
    1419:2005,
    1414:2020,
    1375:2002,
    1165:2022,
    1155:2024,
    878:2022

}

# Loop through dictionary and assign year
for idx, year in movie_years.items():
    Movie_Data.loc[idx, 'YEAR'] = year

# %%
Movie_Data['MOVIES']=Movie_Data['MOVIES'].str.replace(r'[+/\\-]',' ',regex=True)

# %%
Movie_Data['GENRE'] = Movie_Data['GENRE'].str.replace(r'[\n]','',regex=True)

# %%
Movie_Data['ONE-LINE'] = Movie_Data['ONE-LINE'].str.replace("\n","")

# %%
Movie_Data['ONE-LINE'] = Movie_Data['ONE-LINE'].str.strip()

# %%
Movie_Data.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %%
Movie_Data['STARS']=Movie_Data['STARS'].str.replace("\n","")

# %%
Movie_Data['STARS']
# Out:
# 0           Director:Peter Thorwarth|     Stars:Peri B...
# 1                       Stars:Chris Wood, Sarah Michel...
# 2                       Stars:Andrew Lincoln, Norman R...
# 3                       Stars:Justin Roiland, Chris Pa...
# 4           Director:Matthias Schweighöfer|     Stars:...
#                               ...
# 9563        Director:Nicolai Rohde|     Stars:Felix Kl...
# 9564
# 9565        Director:Orlando von Einsiedel|     Star:P...
# 9566        Director:Jovanka Vuckovic|     Stars:Morga...
# 9567        Director:Jovanka Vuckovic|     Stars:Morga...
# Name: STARS, Length: 9568, dtype: object

# %%
Movie_Data['YEAR'].isnull().sum()
# Out:
# np.int64(0)

# %%
Movie_Data.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %%
Movie_Data["RATING"].isnull().sum()
# Out:
# np.int64(1400)

# %%
Movie_Data["RATING"]
# Out:
# 0       6.1
# 1       5.0
# 2       8.2
# 3       9.2
# 4       NaN
#        ...
# 9563    NaN
# 9564    NaN
# 9565    NaN
# 9566    NaN
# 9567    NaN
# Name: RATING, Length: 9568, dtype: float64

# %%
Movie_Data["MOVIES"].isnull().sum()
# Out:
# np.int64(0)

# %%
Movie_Data.dtypes
# Out:
# MOVIES       object
# YEAR         object
# GENRE        object
# RATING      float64
# ONE-LINE     object
# STARS        object
# VOTES        object
# RunTime     float64
# Gross        object
# dtype: object

# %%
GENRE_DATE = {
    2124:"adjacent to true crime",
    3144:"Action, Spy, Suspense, Thriller"
}
for idex,genre in GENRE_DATE.items():
    Movie_Data.loc[idex,"GENRE"] = genre

# %% [markdown]
# #### Movies Column Total Clean

# %%
Movie_Data["MOVIES"].sample(20)
# Out:
# 7138                     Comedians in Cars Getting Coffee
# 472     Kôdo giasu   Hangyaku no rurûshu: Code Geass  ...
# 5833                                               Fix Us
# 4618         ReMastered: Tricky Dick and the Man in Black
# 144                        Jumanji: Welcome to the Jungle
# 6142                                  La Sangre del Gallo
# 6759                                             Ultraman
# 3350                  WISH YOU: Your Melody from My Heart
# 7486                                     Jupiter's Legacy
# 7653                                     The Last Kingdom
# 5233                               Les étoiles vagabondes
# 575                                           Steins;Gate
# 6811                                             Lunatics
# 5281                                           Super Zach
# 132                                          The Departed
# 4527                    ReMastered: Who Shot the Sheriff?
# ...

# %%
Movie_Data["MOVIES"] = Movie_Data["MOVIES"].str.title()

# %% [markdown]
# #### Working On Rating Column

# %%
Movie_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9568 non-null   object
#  1   YEAR      9568 non-null   object
#  2   GENRE     9492 non-null   object
#  3   RATING    8168 non-null   float64
#  4   ONE-LINE  9568 non-null   object
#  5   STARS     9568 non-null   object
#  6   VOTES     8168 non-null   object
#  7   RunTime   7008 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 672.9+ KB

# %%
Movie_Data["RATING"].isnull().sum()
# Out:
# np.int64(1400)

# %%
Movie_Data["RATING"].mean()
# Out:
# np.float64(6.919698824681684)

# %%
RATING_MEDIAN = Movie_Data["RATING"].median()

# %%
Movie_Data.fillna({"RATING":RATING_MEDIAN},inplace=True)

# %%
Movie_Data["RATING"].isna().sum()
# Out:
# np.int64(0)

# %%
Movie_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9568 non-null   object
#  1   YEAR      9568 non-null   object
#  2   GENRE     9492 non-null   object
#  3   RATING    9568 non-null   float64
#  4   ONE-LINE  9568 non-null   object
#  5   STARS     9568 non-null   object
#  6   VOTES     8168 non-null   object
#  7   RunTime   7008 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 672.9+ KB

# %%
Movie_Data["STARS"].sample(20)
# Out:
# 8596        Director:Oliver Driver|     Stars:Rorrie D...
# 5452                    Stars:Adesua Etomi-Wellington,...
# 3550        Director:Aaron Lieber|     Stars:Alana Bla...
# 3679        Director:Kivanç Baruönü|     Stars:Gupse O...
# 9072        Director:Ken Whittingham|     Stars:Jamie ...
# 5411        Director:Eddie Mullins|     Stars:Leo Fitz...
# 302                     Stars:Luna Wedler, Jessica Sch...
# 6409        Director:Steve Petersen|     Stars:Johnny ...
# 1884                    Stars:Lee Min-ki, Jung So-Min,...
# 1999                    Stars:Cindy Robinson, Valerie ...
# 2887        Director:Kheiron|     Stars:Kheiron, Cathe...
# 6999                    Stars:Emmanuel Esparza, Essine...
# 1247        Director:Jason Cabell|     Stars:Nicolas C...
# 49          Director:Zack Snyder|     Stars:Dave Bauti...
# 5909        Director:Lancelot Oduwa Imasuen|     Stars...
# 8791        Director:Phil Allora|     Stars:Rachel Egg...
# 9349
# ...

# %%
Movie_Data['DIRECTOR'] = Movie_Data['STARS'].where(Movie_Data['STARS'].str.contains(r'\|')).str.split(r'\|', n=1).str[0]

# %%
Movie_Data['DIRECTOR'].sample(10)
# Out:
# 5506                         Director:Shawn Arranha
# 1175                                            NaN
# 9329                           Director:Jun-hee Han
# 2032                  Director:Naseef Yusuf Izuddin
# 5372                          Director:Neville Shah
# 6603        Directors:Noriyuki Abe, Kazunori Mizuno
# 8708                           Director:Philip Koch
# 1361                                            NaN
# 1384                            Director:Sean Baker
# 7998                                            NaN
# Name: DIRECTOR, dtype: object

# %%
Movie_Data["STARS"].sample(10)
# Out:
# 3744        Director:Lasja Fauzia|     Stars:Jefri Nic...
# 5388        Directors:Matt Danner, Dan Fraga|     Star...
# 2599        Director:Hannes Stöhr|     Stars:Paul Kalk...
# 4265        Director:Gustavo Hernández|     Stars:Adri...
# 1899                    Stars:Grace Beedie, Dakota Tay...
# 7919        Directors:Robert Kenner, Taki Oldham|     ...
# 3701                    Stars:Flower the Meerkat, Moza...
# 5978            Director:Jay Chapman|     Star:Todd Glass
# 8480        Director:Greg Sullivan|     Stars:Ashleigh...
# 2375        Director:Alexandre Espigares|     Stars:Ra...
# Name: STARS, dtype: object

# %%
Movie_Data['STARS'] = Movie_Data['STARS'].str.split(r'\|', n=1).str[1].fillna(Movie_Data['STARS'])

# %%
Movie_Data['STARS'] = Movie_Data['STARS'].str.replace(r'^\s*Stars:\s*', '', regex=True)

# %%
Movie_Data["STARS"].str.title()
# Out:
# 0       Peri Baumeister, Carl Anton Koch, Alexander Sc...
# 1       Chris Wood, Sarah Michelle Gellar, Lena Headey...
# 2       Andrew Lincoln, Norman Reedus, Melissa Mcbride...
# 3       Justin Roiland, Chris Parnell, Spencer Grammer...
# 4       Matthias Schweighöfer, Nathalie Emmanuel, Ruby...
#                               ...
# 9563    Felix Klare, Romina Küper, Anna Maria Mühe, Ro...
# 9564
# 9565                                    Star:Prince Harry
# 9566    Morgan Taylor Campbell, Iñaki Godoy, Rhianna J...
# 9567    Morgan Taylor Campbell, Jennifer Cheon Garcia,...
# Name: STARS, Length: 9568, dtype: object

# %%
Movie_Data["STARS"].sample(10)
# Out:
# 2501    Daym Drops, Sonya Beckham, Teresa Cottrell, Na...
# 260     Elijah Wood, Ian McKellen, Viggo Mortensen, Or...
# 2622    Inori Minase, Kana Hanazawa, Yuka Iguchi, Saor...
# 4341                           Star:Paco Ignacio Taibo II
# 5105    Tom Sizemore, Stacy Keach, Kevin P. Farley, Hé...
# 2913    Bishop Agapit, Catherine Ashton, Serhii Averch...
# 4532    Maureen O'Hara, Alex Nicol, William Bishop, Ro...
# 247     Kent Williams, Iemasa Kayumi, Vic Mignogna, Ro...
# 8692    Colin O'Donoghue, David Bradley, James Faulkne...
# 7858    Carl Malapa, Némo Schiffman, Manon Bresch, Cor...
# Name: STARS, dtype: object

# %%
Movie_Data["STARS"].isna().sum()
# Out:
# np.int64(0)

# %%
Movie_Data['DIRECTOR'] = Movie_Data['DIRECTOR'].str.replace(r'^\s* Director:\s*', '', regex=True)

# %%
Movie_Data["DIRECTOR"].str.title()
# Out:
# 0             Peter Thorwarth
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4       Matthias Schweighöfer
#                 ...
# 9563            Nicolai Rohde
# 9564                      NaN
# 9565    Orlando Von Einsiedel
# 9566         Jovanka Vuckovic
# 9567         Jovanka Vuckovic
# Name: DIRECTOR, Length: 9568, dtype: object

# %%
Movie_Data["DIRECTOR"].sample(10)
# Out:
# 7498         Joss Agnew
# 3292    César Rodrigues
# 8737       Salva Romero
# 3021     Stanley Nelson
# 8626    Bartosz Konopka
# 1462        Jeff Wadlow
# 8947       Helen Shaver
# 5968                NaN
# 5900       Tekin Girgin
# 7559     Fabrice Gobert
# Name: DIRECTOR, dtype: object

# %%
Movie_Data["DIRECTOR"].isna().sum()
# Out:
# np.int64(3692)

# %%
Movie_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9568 non-null   object
#  1   YEAR      9568 non-null   object
#  2   GENRE     9492 non-null   object
#  3   RATING    9568 non-null   float64
#  4   ONE-LINE  9568 non-null   object
#  5   STARS     9568 non-null   object
#  6   VOTES     8168 non-null   object
#  7   RunTime   7008 non-null   float64
#  8   Gross     460 non-null    object
#  9   DIRECTOR  5876 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 747.6+ KB

# %%
Movie_Data["VOTES"]
# Out:
# 0        21,062
# 1        17,870
# 2       885,805
# 3       414,849
# 4           NaN
#          ...
# 9563        NaN
# 9564        NaN
# 9565        NaN
# 9566        NaN
# 9567        NaN
# Name: VOTES, Length: 9568, dtype: object

# %%
Movie_Data["VOTES"] = Movie_Data["VOTES"].str.replace(",","").astype(float)

# %%
Movie_Data["VOTES"] = Movie_Data["VOTES"].astype("Int64")

# %%
moive_vote = int(Movie_Data["VOTES"].median())

# %%
Movie_Data["VOTES"].fillna(moive_vote,inplace=True)

# %%
Movie_Data["VOTES"].isna().sum()
# Out:
# np.int64(0)

# %%
Movie_Data["RunTime"].isna().sum()
# Out:
# np.int64(2560)

# %%
Movie_Data["RunTime"].min()
# Out:
# np.float64(1.0)

# %%
Movie_Data["RunTime"].sample(10)
# Out:
# 6423      NaN
# 6365      NaN
# 3644     40.0
# 6149     85.0
# 7642      NaN
# 3820    139.0
# 1721    125.0
# 2275     97.0
# 2380     25.0
# 2567      NaN
# Name: RunTime, dtype: float64

# %%
Movie_Data.describe()
# Out:
#             RATING         VOTES      RunTime
# count  9568.000000        9568.0  7008.000000
# mean      6.946081  13044.353783    68.874144
# std       1.128978  64966.070182    47.278890
# min       1.100000           5.0     1.000000
# 25%       6.400000        225.75    37.000000
# 50%       7.100000         792.0    60.000000
# 75%       7.600000        2903.0    95.000000
# max       9.900000     1713028.0   853.000000

# %%
Movie_Data[Movie_Data["RunTime"] == Movie_Data["RunTime"].min()]
# Out:
#                                                  MOVIES  YEAR  \
# 2854                                     Horsin' Around  2014
# 2954               Trollhunters: Happy Birthday To You!  2017
# 3378  13 Reasons Why: Season 2 Date Announcement Com...  2018
# 3977  Miraculous: Ladybug & Cat Noir: Happy Birthday...  2017
# 4129                                        Piggy Tales  2014
# 5358                    Pokémon: Happy Birthday To You!  2017
# 5446             My Little Pony: Happy Birthday To You!  2017
# 5682                     Barbie: Happy Birthday To You!  2017
# 5854  Lego Ninjago: Masters Of Spinjitzu: Happy Birt...  2017
# 5872                  Beat Bugs: Happy Birthday To You!  2017
# 5888       All Hail King Julien: Happy Birthday To You!  2017
# 5891                   Dinotrux: Happy Birthday To You!  2017
# 6098         Skylanders Academy: Happy Birthday To You!  2017
# 6385               Lego Friends: Happy Birthday To You!  2017
# ...

# %%
Movie_Data[Movie_Data["RunTime"].isna()]
# Out:
#                                       MOVIES  YEAR  \
# 4                            Army Of Thieves  2021
# 13                                  Sex Life  2021
# 24    He Man And The Masters Of The Universe  2021
# 48                               Sweet Tooth  2021
# 76                           Shadow And Bone  2021
# ...                                      ...   ...
# 9563                               Totenfrau  2022
# 9564                                  Arcane  2021
# 9565                       Heart Of Invictus  2022
# 9566                          The Imperfects  2021
# 9567                          The Imperfects  2021
#
#                                          GENRE  RATING  \
# 4            Action, Crime, Horror                 7.1
# 13          Comedy, Drama, Romance                 5.4
# 24    Animation, Action, Adventure                 7.1
# 48        Action, Adventure, Drama                 7.9
# 76        Action, Adventure, Drama                 7.7
# ...

# %%
Runtime_median =  Movie_Data["RunTime"].median()

# %%
Movie_Data["RunTime"].fillna(Runtime_median,inplace=True)

# %%
Movie_Data["RunTime"].isna().sum()
# Out:
# np.int64(0)

# %%
Movie_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9568 non-null   object
#  1   YEAR      9568 non-null   object
#  2   GENRE     9492 non-null   object
#  3   RATING    9568 non-null   float64
#  4   ONE-LINE  9568 non-null   object
#  5   STARS     9568 non-null   object
#  6   VOTES     9568 non-null   Int64
#  7   RunTime   9568 non-null   float64
#  8   Gross     460 non-null    object
#  9   DIRECTOR  5876 non-null   object
# dtypes: Int64(1), float64(2), object(7)
# memory usage: 757.0+ KB

# %%
Movie_Data["Gross"].isna().sum()
# Out:
# np.int64(9108)

# %%
Movie_Data["Gross"].sample(10)
# Out:
# 2301    NaN
# 4877    NaN
# 7103    NaN
# 4123    NaN
# 1468    NaN
# 7820    NaN
# 7810    NaN
# 1973    NaN
# 2619    NaN
# 9378    NaN
# Name: Gross, dtype: object

# %%
def convert_money(x):
    x = str(x).replace("$", "").replace(",", "")
    
    if "M" in x:
        return float(x.replace("M", "")) * 1_000_000
    
    return float(x)

Movie_Data["Gorss_Money"] = Movie_Data["Gross"].apply(convert_money)

# %%
movie_price = Movie_Data["Gorss_Money"].median()

# %%
Movie_Data["Gorss_Money"].fillna(movie_price,inplace=True)
# Out:
# C:\Users\sitan\AppData\Local\Temp\ipykernel_32728\2534165027.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Movie_Data["Gorss_Money"].fillna(movie_price,inplace=True)

# %%
Movie_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MOVIES       9568 non-null   object
#  1   YEAR         9568 non-null   object
#  2   GENRE        9492 non-null   object
#  3   RATING       9568 non-null   float64
#  4   ONE-LINE     9568 non-null   object
#  5   STARS        9568 non-null   object
#  6   VOTES        9568 non-null   Int64
#  7   RunTime      9568 non-null   float64
#  8   Gross        460 non-null    object
#  9   DIRECTOR     5876 non-null   object
#  10  Gorss_Money  9568 non-null   float64
# dtypes: Int64(1), float64(3), object(7)
# memory usage: 831.7+ KB

# %%
Movie_Data.to_csv("Clean_Movie_Data.csv",index=False)
